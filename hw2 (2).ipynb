# %% [markdown]
# Load mnist dataset

# %% [markdown]
# Define Gaussian and get its parameters.

# %%
import pandas as pd

dataset = pd.read_csv('data.csv')
dataset.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
dataset.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
dataset=dataset.drop(['id','Unnamed: 32'],axis=1)

# %%
dataset.isnull().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
encode_var= dataset.diagnosis
print(encode_var)
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
columnsToEncode=dataset.select_dtypes(include=[object]).columns
dataset = pd.get_dummies(dataset, columns=columnsToEncode)

# %%
dataset.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  perimeter_worst  area_worst  smoothness_worst  \
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
dataset = pd.read_csv('data.csv')
y = dataset['diagnosis']
x= dataset.drop(columns=['diagnosis','Unnamed: 32'])

X_train,X_test,Y_train, Y_test = train_test_split(x, y, test_size=0.2, random_state=9)

# %%
dataset.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
r= RandomForestClassifier(n_estimators=100,random_state=9,n_jobs=-1)
r.fit(X_train,Y_train)

y_predict= r.predict(X_test)

# %%
score_r = r.score(X_test, Y_test)
print(score_r)
# Out:
# 0.9649122807017544

# %%
from sklearn.linear_model import LogisticRegression

l= LogisticRegression()

model= l.fit(X_train,Y_train)
predic= model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_test,predic)
# Out:
# 0.6491228070175439

# %%
import pandas as pd
dataset = pd.read_csv('data.txt')

# %%
dataset = ((dataset - dataset.min()) / (dataset.max() - dataset.min())) * 10 + 1

# %%
dataset
# Out:
#       1000025         5          1        1.1       1.2         2   1.3  \
# 0    1.702853  5.444444   4.333333   4.333333  5.444444  7.666667  11.0
# 1    1.712171  3.222222   1.000000   1.000000  1.000000  2.111111   3.0
# 2    1.712808  6.555556   8.777778   8.777778  1.000000  3.222222   5.0
# 3    1.713365  4.333333   1.000000   1.000000  3.222222  2.111111   2.0
# 4    1.713438  8.777778  11.000000  11.000000  8.777778  7.666667  11.0
# ..        ...       ...        ...        ...       ...       ...   ...
# 693  1.533933  3.222222   1.000000   1.000000  1.000000  3.222222   3.0
# 694  1.582507  2.111111   1.000000   1.000000  1.000000  2.111111   2.0
# 695  1.617639  5.444444  11.000000  11.000000  3.222222  7.666667   4.0
# 696  1.624098  4.333333   8.777778   6.555556  4.333333  3.222222   5.0
# 697  1.624098  4.333333   8.777778   8.777778  5.444444  4.333333   6.0
#
#              3        1.4       1.5   2.1
# 0     3.222222   2.111111  1.000000   1.0
# ...

# %%
def random_centroids(dataset, k):
    centroids = []
    for i in range(k):
        centroid = dataset.apply(lambda x: float(x.sample()))
        centroids.append(centroid)
    return pd.concat(centroids, axis=1)

# %%
random_centroids(dataset, 3)
# Out:
#                  0          1          2
# 1000025   1.954360   1.841989   1.713365
# 5         2.111111   1.000000   3.222222
# 1         1.000000   4.333333   2.111111
# 1.1       1.000000   1.000000   1.000000
# 1.2       4.333333   3.222222   3.222222
# 2         2.111111   2.111111   5.444444
# 1.3      11.000000   2.000000   2.000000
# 3         3.222222   3.222222   6.555556
# 1.4       1.000000  11.000000  11.000000
# 1.5       1.000000   1.000000   1.000000
# 2.1       1.000000   1.000000   1.000000

# %%
centroids = random_centroids(dataset, 5)

# %%
centroids
# Out:
#                  0          1          2          3          4
# 1000025   1.873425   1.920485   1.808159   1.923524   1.601639
# 5         1.000000   2.111111   6.555556   1.000000   3.222222
# 1         5.444444   1.000000   1.000000   6.555556   1.000000
# 1.1       1.000000   1.000000   1.000000   1.000000   1.000000
# 1.2       1.000000   5.444444   3.222222   1.000000   1.000000
# 2         2.111111   2.111111   2.111111   2.111111   2.111111
# 1.3       2.000000   2.000000  11.000000   2.000000  11.000000
# 3         2.111111   3.222222   3.222222   1.000000   2.111111
# 1.4       9.888889   3.222222   1.000000   2.111111   1.000000
# 1.5       1.000000   1.000000   1.000000   1.000000   1.000000
# 2.1      11.000000  11.000000   1.000000  11.000000   1.000000

# %%
import numpy as np
def get_labels(dataset, centroids):
    distances = centroids.apply(lambda x: np.sqrt(((dataset - x) ** 2).sum(axis=1)))
    return distances.idxmin(axis=1)

# %%
labels = get_labels(dataset, centroids)

# %%
labels
# Out:
# 0      2
# 1      4
# 2      2
# 3      2
# 4      0
#       ..
# 693    4
# 694    4
# 695    0
# 696    0
# 697    1
# Length: 698, dtype: int64

# %%
labels.value_counts()
# Out:
# 4    389
# 2    103
# 0    103
# 1     83
# 3     20
# dtype: int64

# %%
def new_centroids(dataset, labels, k):
    centroids = dataset.groupby(labels).apply(lambda x: np.exp(np.log(x).mean())).T
    return centroids

# %%
new_centroids(dataset, labels, 5)
# Out:
#                  0          1         2          3         4
# 1000025   1.695612   1.664314  1.735859   1.800867  1.739826
# 5         7.350001   6.240383  6.963828   6.955872  2.228727
# 1         7.762824   5.102793  2.432654   8.922813  1.134645
# 1.1       7.543252   5.411451  2.658950   8.006795  1.211377
# 1.2       4.897504   5.849375  2.556473   2.600652  1.102680
# 2         5.987049   4.631629  2.906344   5.876059  2.041365
# 1.3       6.879872   6.698836  4.367850   8.267864  2.114342
# 3         6.615625   5.550004  3.341528   5.373666  1.848211
# 1.4       9.922550   3.728208  1.680866   2.015357  1.088274
# 1.5       2.214717   1.733439  1.211821   1.591562  1.028179
# 2.1      10.257957  10.686753  2.479212  11.000000  1.000000

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from IPython.display import clear_output

# %%
def plot_clusters(dataset, labels, centroids, iteration):
    pca = PCA(n_components=2)
    data_2d = pca.fit_transform(dataset)
    centroids_2d = pca.transform(centroids.T)
    clear_output(wait=True)
    plt.title(f'Iteration {iteration}')
    plt.scatter(x=data_2d[:,0], y=data_2d[:,1], c=labels)
    plt.scatter(x=centroids_2d[:,0], y=centroids_2d[:,1])
    plt.show()

# %%
max_iterations = 300
centroid_count = 10

centroids = random_centroids(dataset, centroid_count)
old_centroids = pd.DataFrame()
iteration = 5

while iteration < max_iterations and not centroids.equals(old_centroids):
    old_centroids = centroids
    
    labels = get_labels(dataset, centroids)
    centroids = new_centroids(dataset, labels, centroid_count)
    plot_clusters(dataset, labels, centroids, iteration)
    iteration += 1

# %%
centroids
# Out:
#                  1         2          3          4         5          6  \
# 1000025   1.758100  1.720550   1.575423   1.833198  1.689500   1.649318
# 5         7.528726  1.086568   6.724000   1.000000  5.225895   7.149415
# 1         9.777280  1.063976   4.702286   1.000000  3.840172   3.578696
# 1.1       9.088107  1.136431   4.687783   1.000000  3.762606   4.237744
# 1.2       5.013858  1.083364   8.378084   1.000000  2.435981   1.921917
# 2         6.622809  1.912433   4.173168  11.000000  3.920985   3.552116
# 1.3       7.850811  2.062868  10.121228   2.000000  3.349834   6.633970
# 3         6.666622  1.661318   5.734770   1.000000  3.567878   4.178270
# 1.4       2.208952  1.030399   2.952111   1.000000  3.329040   2.965160
# 1.5       1.644230  1.044429   1.550129   1.000000  1.103719   1.552145
# 2.1      11.000000  1.000000  11.000000   1.000000  1.000000  11.000000
#
#                 7         8          9
# 1000025  1.797019  1.730564   1.715206
# ...

# %%
labels.value_counts()
# Out:
# 7    158
# 2    153
# 8    118
# 9    111
# 6     50
# 3     41
# 1     39
# 5     27
# 4      1
# dtype: int64

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(3)
kmeans.fit(dataset)
# Out:
# KMeans(n_clusters=3)

# %%
pd.DataFrame(kmeans.cluster_centers_).T
# Out:
#             0         1          2
# 0    1.734471  1.782612   1.666267
# 1    7.925647  3.116049   7.753623
# 2    9.086884  1.283951   4.951691
# 3    8.786132  1.422222   5.251208
# 4    7.223893  1.353086   4.623188
# 5    7.106934  2.200000   4.198068
# 6    8.270677  2.222222   8.852174
# 7    7.566416  2.182716   5.222222
# 8    8.360067  1.256790   4.091787
# 9    3.489557  1.064198   1.850242
# 10  10.924812  1.000000  10.478261
